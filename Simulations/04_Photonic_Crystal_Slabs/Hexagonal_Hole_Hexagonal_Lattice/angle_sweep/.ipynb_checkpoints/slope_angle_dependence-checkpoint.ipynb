# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %%
import os
path = os.path.abspath(os.getcwd())
print(path)
# Out:
# /home/ben/Desktop/Thesis/Simulations/05_Photonic_crystal_slabs/Hexagon_hexagonal_lattice/angle_sweep

# %%
for i in range(16):
    globals()["f" + str(i)] = np.genfromtxt(path+"/bands_"+str(i)+".dat", delimiter=",")[:,1:]

# %%
K_index = int(0.33*len(f0[:,1])) 

freq_0 = f0 [K_index, -1]

# %%
frequency_shifts = np.zeros(16)
for i in range(16):
     frequency_shifts [i] =  np.abs( globals()["f" + str(i)] [K_index, -1] - freq_0 )

# %%
coef = np.polyfit(np.linspace(0, 15, 16), frequency_shifts, 1)
poly1d_fn = np.poly1d(coef)

# %%
print(coef)
# Out:
# [0.0006047 0.0019154]

# %%
fig, ax = plt.subplots(figsize=(16,6))

x = np.linspace(0, 15, 16)

ax.set_title('Frequency shift for different design angles')
ax.scatter( x, frequency_shifts, color='black', label = 'Data' )
#ax.plot( x, poly1d_fn(x), color='blue', label = 'Fit: $\\Delta  \\omega a / 2 \pi c$ = '+str(np.around(coef[0],4))+'$\\alpha$ +  '+str(np.around(coef[1],4)))
ax.set_ylabel('$\\Delta  \\omega a / 2 \pi c$ ')
ax.set_xlabel('$\\alpha$ ($^\\circ$)')
# Out:
# Text(0.5, 0, '$\\alpha$ ($^\\circ$)')

# %%
def f(x, A, B):
    return  A*(x)**(B)

# %%
from  scipy.optimize import curve_fit

opt_params, _ = curve_fit(f, x, frequency_shifts)

# %%
opt_params
# Out:
# array([0.00221861, 0.5662103 ])

# %%
ax.plot( np.linspace(0,15,100), f(np.linspace(0,15,100), opt_params[0], opt_params[1]), color='green', label = 'Fit: $\\Delta  \\omega a / 2 \pi c$ = '+str(np.around(opt_params[0],4))+'$\\alpha$**'+str(np.around(opt_params[1],4)))
ax.legend()
fig
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
def f1(x, A, B):
    return  A*(x)+(B)

# %%
from  scipy.optimize import curve_fit

opt_params1, _ = curve_fit(f1, x[1:], frequency_shifts[1:])

# %%
opt_params1
# Out:
# array([0.00054998, 0.0024809 ])

# %%
ax.plot( np.linspace(1,15,100), f1(np.linspace(1,15,100), opt_params1[0], opt_params1[1]), color='blue', label = 'Fit: $\\Delta  \\omega a / 2 \pi c$ = '+str(np.around(opt_params1[0],4))+'$\\alpha$+'+str(np.around(opt_params1[1],4)))
ax.legend()
fig

# %%
save = False
if  save == True:
    fig.savefig('data_and_fit.pdf')
