# %% [markdown]
# # Multilayer film
#
# ## Calculation of band structure

# %% [markdown]
# In this example we will try to **calculate the band structure with the first 2 modes of propagation** in the periodic 1D multilayer film. This 1D photonic crystal can be characterized as:

# %% [markdown]
# <img src="media/multilayer_film.png" width="800">

# %% [markdown]
# First of all, we load the necessary modules:

# %%
import meep as mp
from meep import mpb
import numpy as np

import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %% [markdown]
# We fix the resolution:

# %%
resolution = 128                                                  #we use a power of two number

# %% [markdown]
# We set the width of layers:

# %%
a = 1                                                             #arbitrary units
w = 0.5 * a

# %% [markdown]
# We set the two mediums, with three posibilities for the second medium:

# %%
Med_1 = mp.Medium(index=np.sqrt(13))
Med_2_array = np.array([mp.Medium(index=np.sqrt(13)),mp.Medium(index=np.sqrt(12)),mp.Medium(index=1)])
num = len(Med_2_array)

# %% [markdown]
# Now we define the supercell:

# %%
sc_z = 1 * a  # supercell width

geometry_lattice = mp.Lattice(size=mp.Vector3(0,0,sc_z))

# %% [markdown]
# Now we define the geometry of our problem (remember, that the geometry is centered at $0$ and then takes possitive and negative values around it):

# %%
geometry_array = list()
for i in range(num):
    geometry_array.append([mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,-0.5*w), material=Med_1),mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,+0.5*w), material=Med_2_array[i])])

# %% [markdown]
# We get the data for the permitivity to see if we constructed the unit cell correctly:

# %%
sim = mp.Simulation(resolution=128,
                    cell_size= mp.Vector3(0,0,1),
                    geometry=[mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,-0.5*w), material=Med_1),mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,+0.5*w), material=Med_2_array[2])])

sim.init_sim()

eps_data = sim.get_epsilon()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.05991e-06 s
# Working in 3D dimensions.
# Computational cell is 0.0078125 x 0.0078125 x 1 with resolution 128
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00238991 s
# -----------

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(np.linspace(0,1,len(eps_data)),eps_data)
ax.set_title('Dielectric profile for $\\varepsilon_1=13$ and $\\varepsilon_2=1$')
ax.set_xlabel('z (a units)')
ax.set_ylabel('$\\varepsilon$(z)')
# Out:
# Text(0, 0.5, '$\\varepsilon$(z)')

# %% [markdown]
# As we can see it fulfills the change of $\varepsilon$ at $z=0.5a$, as expected.

# %% [markdown]
# Now we set up the $k$-space (in our case we take into account that we want to check for the $k_z$ component):

# %%
num_bands = 6

num_k = 20
k_min = -0.5
k_max = 0.5

k_points = mp.interpolate(num_k, [mp.Vector3(0,0,k_min), mp.Vector3(0,0,k_max)])

# %% [markdown]
# We can now call the run function to compute the bands:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=k_points,
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 128.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 22 k-points
#   Vector3<0.0, 0.0, -0.5>
#   Vector3<0.0, 0.0, -0.4523809523809524>
#   Vector3<0.0, 0.0, -0.40476190476190477>
#   Vector3<0.0, 0.0, -0.35714285714285715>
#   Vector3<0.0, 0.0, -0.30952380952380953>
#   Vector3<0.0, 0.0, -0.2619047619047619>
#   Vector3<0.0, 0.0, -0.2142857142857143>
#   Vector3<0.0, 0.0, -0.16666666666666669>
#   Vector3<0.0, 0.0, -0.11904761904761907>
#   Vector3<0.0, 0.0, -0.07142857142857145>
#   Vector3<0.0, 0.0, -0.023809523809523836>
#   Vector3<0.0, 0.0, 0.023809523809523725>
#   Vector3<0.0, 0.0, 0.0714285714285714>
#   Vector3<0.0, 0.0, 0.11904761904761907>
#   Vector3<0.0, 0.0, 0.16666666666666663>
#   Vector3<0.0, 0.0, 0.2142857142857142>
#   Vector3<0.0, 0.0, 0.26190476190476186>
#   Vector3<0.0, 0.0, 0.30952380952380953>
#   Vector3<0.0, 0.0, 0.3571428571428571>
#   Vector3<0.0, 0.0, 0.40476190476190466>
#   Vector3<0.0, 0.0, 0.45238095238095233>
#   Vector3<0.0, 0.0, 0.5>
# elapsed time for initialization: 0.022746801376342773
# solve_kpoint (0,0,-0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# freqs:, 1, 0, 0, -0.5, 0.5, 0.150861, 0.150861, 0.256562, 0.256562, 0.590903, 0.590903
# elapsed time for k point: 0.010194778442382812
# solve_kpoint (0,0,-0.452381):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# freqs:, 2, 0, 0, -0.452381, 0.452381, 0.147703, 0.147703, 0.259491, 0.259491, 0.588719, 0.588719
# elapsed time for k point: 0.009823322296142578
# solve_kpoint (0,0,-0.404762):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 3, 0, 0, -0.404762, 0.404762, 0.139119, 0.139119, 0.267371, 0.267371, 0.582597, 0.582597
# elapsed time for k point: 0.015102863311767578
# solve_kpoint (0,0,-0.357143):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 4, 0, 0, -0.357143, 0.357143, 0.12685, 0.12685, 0.278402, 0.278402, 0.573538, 0.573538
# elapsed time for k point: 0.009902477264404297
# solve_kpoint (0,0,-0.309524):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 5, 0, 0, -0.309524, 0.309524, 0.112326, 0.112326, 0.29105, 0.29105, 0.562631, 0.562631
# elapsed time for k point: 0.011614322662353516
# solve_kpoint (0,0,-0.261905):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 6, 0, 0, -0.261905, 0.261905, 0.0964358, 0.0964358, 0.304253, 0.304253, 0.550819, 0.550819
# elapsed time for k point: 0.009150981903076172
# solve_kpoint (0,0,-0.214286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 7, 0, 0, -0.214286, 0.214286, 0.0796977, 0.0796977, 0.317226, 0.317226, 0.538904, 0.538904
# elapsed time for k point: 0.007762908935546875
# solve_kpoint (0,0,-0.166667):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 8, 0, 0, -0.166667, 0.166667, 0.0624195, 0.0624195, 0.329258, 0.329258, 0.527648, 0.527648
# elapsed time for k point: 0.010615348815917969
# solve_kpoint (0,0,-0.119048):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 9, 0, 0, -0.119048, 0.119048, 0.044795, 0.044795, 0.339572, 0.339572, 0.517876, 0.517876
# elapsed time for k point: 0.011454343795776367
# solve_kpoint (0,0,-0.0714286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 10, 0, 0, -0.0714286, 0.0714286, 0.0269552, 0.0269552, 0.347271, 0.347271, 0.510521, 0.510521
# elapsed time for k point: 0.008983135223388672
# solve_kpoint (0,0,-0.0238095):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 11, 0, 0, -0.0238095, 0.0238095, 0.00899761, 0.00899761, 0.351434, 0.351434, 0.506523, 0.506523
# elapsed time for k point: 0.010921716690063477
# solve_kpoint (0,0,0.0238095):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 12, 0, 0, 0.0238095, 0.0238095, 0.00899761, 0.00899761, 0.351434, 0.351434, 0.506523, 0.506523
# elapsed time for k point: 0.010810136795043945
# solve_kpoint (0,0,0.0714286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 13, 0, 0, 0.0714286, 0.0714286, 0.0269552, 0.0269552, 0.347271, 0.347271, 0.510521, 0.510521
# elapsed time for k point: 0.011305809020996094
# solve_kpoint (0,0,0.119048):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 14, 0, 0, 0.119048, 0.119048, 0.044795, 0.044795, 0.339572, 0.339572, 0.517876, 0.517876
# elapsed time for k point: 0.00861811637878418
# solve_kpoint (0,0,0.166667):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 15, 0, 0, 0.166667, 0.166667, 0.0624195, 0.0624195, 0.329258, 0.329258, 0.527648, 0.527648
# elapsed time for k point: 0.008349895477294922
# solve_kpoint (0,0,0.214286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 16, 0, 0, 0.214286, 0.214286, 0.0796977, 0.0796977, 0.317226, 0.317226, 0.538904, 0.538904
# elapsed time for k point: 0.00938868522644043
# solve_kpoint (0,0,0.261905):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 17, 0, 0, 0.261905, 0.261905, 0.0964358, 0.0964358, 0.304253, 0.304253, 0.550819, 0.550819
# elapsed time for k point: 0.009181499481201172
# solve_kpoint (0,0,0.309524):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 18, 0, 0, 0.309524, 0.309524, 0.112326, 0.112326, 0.29105, 0.29105, 0.562631, 0.562631
# elapsed time for k point: 0.011260032653808594
# solve_kpoint (0,0,0.357143):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 19, 0, 0, 0.357143, 0.357143, 0.12685, 0.12685, 0.278402, 0.278402, 0.573538, 0.573538
# elapsed time for k point: 0.00903177261352539
# solve_kpoint (0,0,0.404762):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 20, 0, 0, 0.404762, 0.404762, 0.139119, 0.139119, 0.267371, 0.267371, 0.582597, 0.582597
# elapsed time for k point: 0.008457183837890625
# solve_kpoint (0,0,0.452381):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# freqs:, 21, 0, 0, 0.452381, 0.452381, 0.147703, 0.147703, 0.259491, 0.259491, 0.588719, 0.588719
# elapsed time for k point: 0.009543895721435547
# solve_kpoint (0,0,0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# freqs:, 22, 0, 0, 0.5, 0.5, 0.150861, 0.150861, 0.256562, 0.256562, 0.590903, 0.590903
# elapsed time for k point: 0.009664058685302734
# Band 1 range: 0.00899761101344681 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.15086142995200635 at Vector3<0.0, 0.0, 0.5>
# Band 2 range: 0.008997611397335748 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.15086142995200655 at Vector3<0.0, 0.0, 0.5>
# Band 3 range: 0.2565615680696173 at Vector3<0.0, 0.0, 0.5> to 0.3514344830656799 at Vector3<0.0, 0.0, 0.023809523809523725>
# Band 4 range: 0.25656156806961783 at Vector3<0.0, 0.0, 0.5> to 0.3514344831079736 at Vector3<0.0, 0.0, 0.023809523809523725>
# Band 5 range: 0.5065232150994985 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.5909026322954992 at Vector3<0.0, 0.0, 0.5>
# Band 6 range: 0.5065232151248932 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.590902632593384 at Vector3<0.0, 0.0, -0.5>
# Gap from band 2 (0.15086142995200655) to band 3 (0.2565615680696173), 51.88717310062144%
# Gap from band 4 (0.3514344831079736) to band 5 (0.5065232150994985), 36.15300202225616%
# total elapsed time for run: 0.2537839412689209
# done

# %% [markdown]
# We see that it works!

# %% [markdown]
# Now, we have passed everything down to `ms.py` and run for the three different geometries. We then generate some **band files** to plot them later. This was done by means of the `grep` command, i.e.: `grep freqs: data1.dat > bands_1.dat`. To access these files:

# %%
import os
path = os.path.abspath(os.getcwd())
print(path)
# Out:
# /home/ben/Desktop/Thesis/github/Thesis_name/Simulations/01_Multilayer_Film/General_Multilayer_Film

# %%
f1 = np.genfromtxt(path+"/data/bands_1.dat", delimiter=",")[:-1,1:]
f2 = np.genfromtxt(path+"/data/bands_2.dat", delimiter=",")[:-1,1:]
f3 = np.genfromtxt(path+"/data/bands_3.dat", delimiter=",")[:-1,1:]

# %% [markdown]
# Now we plot the first two bands:

# %%
plt.rcParams.update({'font.size': 22})
fig, ax = plt.subplots(1,3, figsize=(22,8))
f = [f1,f2,f3]
titles = ["For $\\varepsilon_2$=13","For $\\varepsilon_2$=12", "For $\\varepsilon_2$=1"]
for i in range(num):

    ax[i].plot(f[i][:,3], f[i][:,-8], color='black', label="dielectric band") #in the files we calculated 8 bands, and we take the first 2! 
    ax[i].plot(f[i][:,3], f[i][:,-6], color='blue', label="air band") # TE and TM modes will be the same so we jump by 2
    if i>0:
        ax[i].fill_between(f[i][:,3], np.ones(len(f[i][:,3]))*np.max(f[i][:,-8]), np.ones(len(f[i][:,3]))*np.min(f[i][:,-6]), color= 'yellow', alpha=0.7, label="photonic band gap")   
    ax[i].set_title(titles[i])
    ax[i].set_xlabel("Normalized $k_z$")
    ax[i].set_ylabel("$\omega$")
    ax[i].set_ylim(0,0.29)
ax[0].text(0.2, 0.22, "air band", color='blue', bbox=dict(facecolor='white', alpha=0.9, boxstyle='round', edgecolor='blue'))
ax[0].text(-0.4, 0.05, "dielectric band", bbox=dict(facecolor='white', alpha=0.9, boxstyle='round'))
ax[1].text(0.2, 0.22, "air band", color='blue', bbox=dict(facecolor='white', alpha=0.9, boxstyle='round', edgecolor='blue'))
ax[1].text(-0.4, 0.05, "dielectric band", bbox=dict(facecolor='white', alpha=0.9, boxstyle='round'))
ax[1].text(-0.25, 0.16, "photonic band gap", bbox=dict(facecolor='yellow', alpha=0.9, boxstyle='round'))
ax[2].text(0.05, 0.26, "air band", color='blue', bbox=dict(facecolor='white', alpha=0.9, boxstyle='round', edgecolor='blue'))
ax[2].text(-0.4, 0.05, "dielectric band", bbox=dict(facecolor='white', alpha=0.9, boxstyle='round'))
ax[2].text(-0.275, 0.205, "photonic band gap", bbox=dict(facecolor='yellow', alpha=0.9, boxstyle='round'))
# Out:
# Text(-0.275, 0.205, 'photonic band gap')

# %%
fig.savefig("media/band_diagrams_dielectric_contrast.pdf")

# %% [markdown]
# In the first case, we expect the modes to lie along the light line: $\omega (k) = \frac{c k}{\sqrt(\varepsilon)}$.

# %% [markdown]
# We also see the **appearance of a band-gap when the contrast of dielectric index is increased**!

# %% [markdown]
# ## Calculation of electromagnetic fields

# %% [markdown]
# Let's now see how to visualize the electric field related to both of these modes at the edge ($k=\frac{\pi}{a}$). First we simulate for the last geometry at the $k$ point:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0.5)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 128.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.5>
# elapsed time for initialization: 0.039864301681518555
# solve_kpoint (0,0,0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# freqs:, 1, 0, 0, 0.5, 0.5, 0.150861, 0.150861, 0.256562, 0.256562, 0.590903, 0.590903
# elapsed time for k point: 0.015215635299682617
# total elapsed time for run: 0.055252790451049805
# done

# %% [markdown]
# Now we get the real part of the electric field and calculate three periods for visualization purposes:

# %%
efield1 = np.real(np.reshape(ms.get_efield(2)[:,:,:,0],resolution)) # X component of field
efield2 = np.real(np.reshape(ms.get_efield(3) [:,:,:,0],resolution)) # X component of field
efield1 = np.hstack([efield1,-efield1,efield1])
efield2 = np.hstack([efield2,-efield2,efield2])

# %% [markdown]
# Finally, we can plot the electric field for the first two bands on top of our geometry:

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(2,1,figsize=(16,12))
pos0 = ax[0].imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax[0])
ax[0].plot(efield1*300+60, c='r', linewidth=4)
ax[0].invert_yaxis()
ax[0].set_title("$E$ field for mode at top of dielectric band")
pos1 = ax[1].imshow(eps, cmap='Blues', )
fig.colorbar(pos1,ax=ax[1])
ax[1].plot(efield2*110+60, c='r', linewidth=4)
ax[1].invert_yaxis()
ax[1].set_title("$E$ field for mode at bottom of air band")
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

for axis in ax:
    axis.set_xticks([])
    axis.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.87871, 50.7812% > 1, 50% "fill"

# %%
fig.savefig("media/electric_field_frequecy_gap.pdf")

# %% [markdown]
# We can clearly see that **the electric field at top of band 1 has a higher frequency than the electric field at the bottom of band 2**!

# %% [markdown]
# Now, we want to see if the fields are stationary for different $k$-points. In theory, judging by the band structure, we should see that at $k=0$ and $k=\frac{\pi}{2 a}$ the group velocity goes to zero. This means that we expect stationary modes. At an intermediate $k$ we should see a propagating electric field. Let's put this to the test, starting with $k=\frac{\pi}{2 a}$:

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],resolution) # X component of field
efield2 = np.reshape(ms.get_efield(3) [:,:,:,0],resolution) # X component of field
efield1 = np.hstack([efield1,-efield1,efield1])
efield2 = np.hstack([efield2,-efield2,efield2])

# %%
def add_phase(field, phase):
    import cmath
    r = np.zeros(len(field))
    theta = np.zeros(len(field))
    for i in range(len(field)):
        r[i],theta[i] = cmath.polar(field[i])
    theta += np.ones(len(field))*phase
    new_field = np.zeros(np.shape(field), dtype=np.complex_)
    for i in range(len(field)):
        new_field[i] = cmath.rect(r[i],theta[i])
    return  new_field

# %%
phases = np.linspace(0, 2*np.pi, 360)
fields = np.zeros((len(phases),np.size(efield1)), dtype=np.complex_)
for i in range(len(phases)):
    fields[i, :] = add_phase(efield1, phases[i])
fields = np.real(fields)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$ evolving with time')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)
ax.set_xticks([])
ax.set_yticks([])
line, = ax.plot([], [], lw=3, c='red')


def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0,len(efield1),len(efield1))
    y = fields[i]*300+60
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=10, blit=True)


anim.save('media/electric_field1_k_edge.gif')

# %% [markdown]
# It looks as if the electric field is stationary, as we would expect!

# %% [markdown]
# Now, let's try for $k=0$:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 128.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.016619443893432617
# solve_kpoint (0,0,0):
# Solving for bands 3 to 6...
# Finished solving for bands 3 to 6 after 11 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.351972, 0.351972, 0.506006, 0.506006
# elapsed time for k point: 0.0071866512298583984
# total elapsed time for run: 0.023947954177856445
# done

# %%
def get_dephase(field):
    import cmath
    _ , theta0 = cmath.polar(field[0])
    _ , theta1 = cmath.polar(field[-1])
    return (theta1-theta0)

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],resolution) # X component of field
dephase = get_dephase(efield1)
efield1 = np.hstack([np.real(efield1),np.real(add_phase(efield1, dephase)),np.real(add_phase(efield1, 2*dephase))])

# %% [markdown]
# We have to correct the phase so it makes sense!

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax)
ax.plot(efield1+60, c='r', linewidth=4)
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

ax.set_xticks([])
ax.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.87871, 50.7812% > 1, 50% "fill"
# []

# %%
phases = np.linspace(0, 8*np.pi, 360)
fields = np.zeros((len(phases),np.size(efield1)), dtype=np.complex_)
for i in range(len(phases)):
    fields[i, :] = add_phase(efield1, phases[i])
fields = np.real(fields)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$ evolving with time')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)
ax.set_xticks([])
ax.set_yticks([])
line, = ax.plot([], [], lw=3, c='red')


def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0,len(efield1),len(efield1))
    y = fields[i]*500+250
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


anim.save('media/electric_field1_k_0.gif')

# %% [markdown]
# Now, let's try for $k=0.25$:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0.25)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 128.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.25>
# elapsed time for initialization: 0.0169527530670166
# solve_kpoint (0,0,0.25):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# freqs:, 1, 0, 0, 0.25, 0.25, 0.0923161, 0.0923161, 0.307545, 0.307545, 0.54782, 0.54782
# elapsed time for k point: 0.008297204971313477
# total elapsed time for run: 0.02538895606994629
# done

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],resolution) # X component of field
dephase = get_dephase(efield1)
efield1 = np.hstack([np.real(efield1),np.real(add_phase(efield1, dephase)),np.real(add_phase(efield1, 2*dephase))])

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax)
ax.plot(efield1*100+60, c='r', linewidth=4)
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

ax.set_xticks([])
ax.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.87871, 50.7812% > 1, 50% "fill"
# []

# %% [markdown]
# The dephase doesn't seem to have worked perfectly, probably due to our space discretization with the resolution!

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],resolution)
dephase = get_dephase(efield1)
efield1 = np.hstack([efield1,add_phase(efield1, dephase),add_phase(efield1, 2*dephase)])

phases = np.linspace(0, 8*np.pi, 360)
fields = np.zeros((len(phases),np.size(efield1)), dtype=np.complex_)
for i in range(len(phases)):
    fields[i, :] = add_phase(efield1, phases[i])
fields = np.real(fields)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$ evolving with time')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)
ax.set_xticks([])
ax.set_yticks([])
line, = ax.plot([], [], lw=3, c='red')


def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0,len(efield1),len(efield1))
    y = fields[i]*100+60
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


anim.save('media/electric_field1_k_middle.gif')

# %% [markdown]
# ## Calculation of electromagnetic fields

# %% [markdown]
# Now we want to check the electric energy density of the field to understand the nature of the gap:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0.5)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 128.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.5>
# elapsed time for initialization: 0.030713558197021484
# solve_kpoint (0,0,0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# freqs:, 1, 0, 0, 0.5, 0.5, 0.150861, 0.150861, 0.256562, 0.256562, 0.590903, 0.590903
# elapsed time for k point: 0.014338493347167969
# total elapsed time for run: 0.04529070854187012
# done

# %%
ms.get_dfield(2)
ms.compute_field_energy()
N = 128
energy0 = np.zeros(N)
for i in range(N):
    energy0 [i] = ms.get_energy_point(mp.Vector3(0,0,-0.5+(i/N)))
energy0 = np.hstack([energy0,energy0,energy0])
# Out:
# D-energy-components:, 1, 2, 0.844867, 0.155133, 0

# %%
ms.get_dfield(3)
ms.compute_field_energy()
energy1 = np.zeros(N)
for i in range(N):
    energy1 [i] = ms.get_energy_point(mp.Vector3(0,0,-0.5+(i/N)))
energy1 = np.hstack([energy1,energy1,energy1])
# Out:
# D-energy-components:, 1, 3, 0.198259, 0.801741, 0

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(2,1,figsize=(16,12))
pos0 = ax[0].imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax[0])
ax[0].plot(energy0*45, c='r', linewidth=4)
ax[0].invert_yaxis()
ax[0].set_title('Local energy density in $E$ field for mode at top of dielectric band')
pos1 = ax[1].imshow(eps, cmap='Blues', )
ax[0].fill_between(np.linspace(0,resolution*3,resolution*3),energy0*45, facecolor='red', alpha=0.5)
fig.colorbar(pos1,ax=ax[1])
ax[1].plot(energy1*30, c='r', linewidth=4)
ax[1].fill_between(np.linspace(0,resolution*3,resolution*3),energy1*30, facecolor='red', alpha=0.5)
ax[1].invert_yaxis()
ax[1].set_title('Local energy density in $E$ field for mode at bottom of air band')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

for axis in ax:
    axis.set_xticks([])
    axis.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.87871, 50.7812% > 1, 50% "fill"

# %%
fig.savefig("media/energy_field_frequecy_gap.pdf")

# %% [markdown]
# As we can see, **the energy tends to concentrate around high-$\varepsilon$ layers!** The gap arises from the difference in energy location.
