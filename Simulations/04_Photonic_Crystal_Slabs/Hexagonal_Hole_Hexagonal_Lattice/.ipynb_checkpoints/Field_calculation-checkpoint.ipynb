# %%
import meep as mp
from meep import mpb

import numpy as np

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %%
import sys
sys.path.append("/home/ben/Desktop/Thesis/github/Thesis_name/Simulations/")
from ExternalFunctions import (calculate_ifield, plot_field_2D_YZ,  plot_field_2D_XZ,
                              plot_field_2D_XY, plot_intentsity_in_z_axis, geom_hexagon_PCS,
                              plot_unit_cell_cross_sections, plot_epsilon_XY)

# %%
save = True
plot = True
simulate = False

# %%
resolution = 32
num_bands = 6

# %%
a = 405 # nm
t = 180 / a
scaling = (1-t)*0.5

# %%
sx = 1 
sy = 1 
sz = 10
cell = mp.Vector3(sx, sy, sz)

# %%
parameters = [a, t, scaling]
geometry, geometry_lattice = geom_hexagon_PCS (parameters, cell)

# %%
sim_params = resolution, cell, geometry
if plot == True:
    fig,  ax = plot_unit_cell_cross_sections(a, sim_params)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 6.91414e-06 s
# Working in 3D dimensions.
# Computational cell is 1 x 1 x 10 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.444444)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.97404,3.97404,3.97404)
#      prism, center = (0,0,0)
#           height 0.444444, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.185185,0.185185,-0.222222)
#           (0.37037,-0.185185,-0.222222)
#           (0.185185,-0.37037,-0.222222)
#           (-0.185185,-0.185185,-0.222222)
#           (-0.37037,0.185185,-0.222222)
#           (-0.185185,0.37037,-0.222222)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 1.80379 s
# -----------

# %%
num_bands = 4
k_point = mp.Vector3(0.0,0.0,0.0)

sim_params = [geometry_lattice,  k_point, geometry, resolution, num_bands]

num_period = 3

xlim = [-520,520]
ylim = [-520,520]

title = 'XY cross section of 3 unit cells of the PCS'

if plot == True:
    fig, ax = plot_epsilon_XY (sim_params, a, num_period, xlim,  ylim, title, custom_material=False)
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 32 x 32 x 320.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 10)
# Cell volume = 8.66025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 0.1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.444444)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 0.444444, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.185185,0.185185,-0.222222)
#           (0.37037,-0.185185,-0.222222)
#           (0.185185,-0.37037,-0.222222)
#           (-0.185185,-0.185185,-0.222222)
#           (-0.37037,0.185185,-0.222222)
#           (-0.185185,0.37037,-0.222222)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.4891793727874756
# solve_kpoint (0,0,0):
# Solving for bands 3 to 4...
# Finished solving for bands 3 to 4 after 13 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.0929407, 0.092992
# elapsed time for k point: 5.136940002441406
# total elapsed time for run: 5.626275062561035
# done
# epsilon: 1-3.97404, mean 1.09156, harm. mean 1.02492, 3.43964% > 1, 3.07881% "fill"

# %%
num_period = 3
k_point = mp.Vector3(2/3,1/3,0.0) #K point

sim_params = geometry_lattice,  k_point, geometry, resolution, num_bands

field, converted_eps = calculate_ifield(sim_params, num_period)
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 32 x 32 x 320.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 10)
# Cell volume = 8.66025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 0.1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.444444)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 0.444444, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.185185,0.185185,-0.222222)
#           (0.37037,-0.185185,-0.222222)
#           (0.185185,-0.37037,-0.222222)
#           (-0.185185,-0.185185,-0.222222)
#           (-0.37037,0.185185,-0.222222)
#           (-0.185185,0.37037,-0.222222)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.6666666666666666, 0.3333333333333333, 0.0>
# elapsed time for initialization: 0.4734501838684082
# solve_kpoint (0.666667,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 18 iterations.
# freqs:, 1, 0.666667, 0.333333, 0, 0.666667, 0.451443, 0.527319, 0.527845, 0.547109
# elapsed time for k point: 15.076907396316528
# Fixing e-field (band 1) phase by -0.768922 + 0.639343i; max ampl. = 1.05096
# Fixing e-field (band 2) phase by -0.856893 + -0.515494i; max ampl. = 1.69143
# Fixing e-field (band 3) phase by 0.103379 + 0.994642i; max ampl. = 1.5115
# Fixing e-field (band 4) phase by -0.428441 + 0.90357i; max ampl. = 1.61785
# total elapsed time for run: 15.913485527038574
# done
# epsilon: 1-3.97404, mean 1.09156, harm. mean 1.02492, 3.43964% > 1, 3.07881% "fill"

# %%
num_band = 0

# %%
eps = converted_eps.T
a = 290  # nanometers


ylim = [-375,375]
zlim = [-375,375]
title = 'YZ projection of I field'

plot_field_2D_YZ(eps, np.array(field), a, resolution, num_band, ylim, zlim, title)
# Out:
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:title={'center':'YZ projection of I field'}, xlabel='Z distance (nm)', ylabel='Y distance (nm)'>)

# %%
eps = converted_eps.T
a = 290  # nanometers


xlim = [-375,375]
ylim = [-375,375]
title = 'XY projection of I field'

plot_field_2D_XY(eps, np.array(field), a, resolution, num_band, xlim, ylim, title)
# Out:
# 7 89 0 82
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:title={'center':'XY projection of I field'}, xlabel='X distance (nm)', ylabel='Y distance (nm)'>)

# %%
eps = converted_eps.T
a = 290  # nanometers


xlim = [-375,375]
zlim = [-375,375]
title = 'XZ projection of I field'

plot_field_2D_XZ(eps, np.array(field), a, resolution, num_band, xlim, zlim, title)
# Out:
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:title={'center':'XZ projection of I field'}, xlabel='Z distance (nm)', ylabel='X distance (nm)'>)
