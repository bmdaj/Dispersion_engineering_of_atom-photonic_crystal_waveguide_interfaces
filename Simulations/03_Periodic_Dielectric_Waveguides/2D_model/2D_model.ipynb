# %%
import meep as mp
from meep import mpb

import numpy as np

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %% [markdown]
# # 2 dimensional model

# %% [markdown]
# # Periodic dielectric waveguides

# %% [markdown]
# This model will be periodic in one direction only, which will lead to a Photonic Band Gap in this direction and to index guiding in the other direction.

# %% [markdown]
# We will havee a strips like this:

# %% [markdown]
# <img src="media/2D_model.png" width="700">

# %% [markdown]
# Both structures have translational symmetry in $X$, therefore $k_x$ is conserved.

# %% [markdown]
# ## Band structure calculation

# %% [markdown]
# We fix the usual initialization parameters:

# %%
resolution = 32

Med_1 = mp.Medium(index=np.sqrt(12))
Med_2 = mp.Medium(index=1)

a = 1  #Arbitrary units

width = 0.4 * a

sc = 1 * a  
y_lim = 5


geometry_lattice = mp.Lattice(size=mp.Vector3(sc,y_lim))
geometry = [mp.Block(size=mp.Vector3(width, width),
            center=mp.Vector3(0.5*(width-sc),0), material=Med_1)]

# %%
cell_size = mp.Vector3(sc,y_lim)

sim = mp.Simulation(resolution=resolution,
                    cell_size= cell_size,
                    geometry=geometry)
sim.init_sim()
eps_data = sim.get_epsilon()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 5.96046e-06 s
# Working in 2D dimensions.
# Computational cell is 1 x 5 x 0 with resolution 32
#      block, center = (-0.3,0,0)
#           size (0.4,0.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.00883317 s
# -----------

# %% [markdown]
# We plot 3 unit cells to make sure the geometry is correct:

# %%
eps = np.concatenate([eps_data,eps_data,eps_data]).T #three unit cells in one direction

fig1, ax1 = plt.subplots(figsize=(10,6))
ax1.set_title('3 unit cells of the 2D photonic crystal')
pos1 = ax1.imshow(eps, interpolation='spline36', cmap='binary')
ax1.axis('off')
# Out:
# (-0.5, 95.5, 159.5, -0.5)

# %% [markdown]
# We fix the $k$ points for our simulation:

# %%
num_bands = 10

num_k = 20
k_min = 0
k_max = 1

k_points = mp.interpolate(num_k, [mp.Vector3(k_min), mp.Vector3(k_max)])

# %% [markdown]
# We compute the bands:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry,
                    k_points=k_points,
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 160 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 5, 0)
#      (0, 0, 1)
# Cell volume = 5
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.2, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (-0.3,0,0)
#           size (0.4,0.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 22 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.047619047619047616, 0.0, 0.0>
#   Vector3<0.09523809523809523, 0.0, 0.0>
#   Vector3<0.14285714285714285, 0.0, 0.0>
#   Vector3<0.19047619047619047, 0.0, 0.0>
#   Vector3<0.23809523809523808, 0.0, 0.0>
#   Vector3<0.2857142857142857, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38095238095238093, 0.0, 0.0>
#   Vector3<0.42857142857142855, 0.0, 0.0>
#   Vector3<0.47619047619047616, 0.0, 0.0>
#   Vector3<0.5238095238095237, 0.0, 0.0>
#   Vector3<0.5714285714285714, 0.0, 0.0>
#   Vector3<0.6190476190476191, 0.0, 0.0>
#   Vector3<0.6666666666666666, 0.0, 0.0>
#   Vector3<0.7142857142857142, 0.0, 0.0>
#   Vector3<0.7619047619047619, 0.0, 0.0>
#   Vector3<0.8095238095238095, 0.0, 0.0>
#   Vector3<0.8571428571428571, 0.0, 0.0>
#   Vector3<0.9047619047619047, 0.0, 0.0>
#   Vector3<0.9523809523809523, 0.0, 0.0>
#   Vector3<1.0, 0.0, 0.0>
# elapsed time for initialization: 0.037355661392211914
# solve_kpoint (0,0,0):
# Solving for bands 3 to 10...
# Finished solving for bands 3 to 10 after 15 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.158841, 0.186681, 0.198726, 0.199064, 0.335609, 0.376795, 0.38449, 0.38855
# elapsed time for k point: 0.471541166305542
# solve_kpoint (0.047619,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# freqs:, 2, 0.047619, 0, 0, 0.047619, 0.0414087, 0.0463562, 0.163627, 0.192618, 0.204035, 0.20427, 0.338304, 0.37971, 0.387016, 0.390863
# elapsed time for k point: 0.31055116653442383
# solve_kpoint (0.0952381,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# freqs:, 3, 0.0952381, 0, 0, 0.0952381, 0.0814376, 0.0926235, 0.177632, 0.20942, 0.218245, 0.220057, 0.346287, 0.388319, 0.39444, 0.397682
# elapsed time for k point: 0.35323596000671387
# solve_kpoint (0.142857,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# freqs:, 4, 0.142857, 0, 0, 0.142857, 0.118423, 0.138694, 0.200177, 0.234759, 0.240002, 0.244084, 0.359245, 0.402241, 0.406309, 0.408658
# elapsed time for k point: 0.3593301773071289
# solve_kpoint (0.190476,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# freqs:, 5, 0.190476, 0, 0, 0.190476, 0.150796, 0.184414, 0.230487, 0.266201, 0.267395, 0.274149, 0.376588, 0.420922, 0.421885, 0.423217
# elapsed time for k point: 0.43360042572021484
# solve_kpoint (0.238095,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# freqs:, 6, 0.238095, 0, 0, 0.238095, 0.178138, 0.229544, 0.267022, 0.298821, 0.301832, 0.308418, 0.397205, 0.440128, 0.440502, 0.443716
# elapsed time for k point: 0.4346327781677246
# solve_kpoint (0.285714,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# freqs:, 7, 0.285714, 0, 0, 0.285714, 0.201084, 0.273683, 0.307605, 0.333151, 0.34032, 0.345506, 0.418446, 0.458978, 0.459612, 0.469946
# elapsed time for k point: 0.5288693904876709
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 11 iterations.
# freqs:, 8, 0.333333, 0, 0, 0.333333, 0.220164, 0.316176, 0.350358, 0.369742, 0.380769, 0.384322, 0.433373, 0.474705, 0.478469, 0.498924
# elapsed time for k point: 0.6096920967102051
# solve_kpoint (0.380952,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 12 iterations.
# freqs:, 9, 0.380952, 0, 0, 0.380952, 0.235338, 0.356052, 0.393434, 0.408312, 0.422564, 0.423684, 0.437223, 0.478925, 0.494817, 0.529841
# elapsed time for k point: 0.6195390224456787
# solve_kpoint (0.428571,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 13 iterations.
# freqs:, 10, 0.428571, 0, 0, 0.428571, 0.246097, 0.39216, 0.424435, 0.448081, 0.448699, 0.460915, 0.465218, 0.469851, 0.508795, 0.560651
# elapsed time for k point: 0.6302294731140137
# solve_kpoint (0.47619,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 18 iterations.
# freqs:, 11, 0.47619, 0, 0, 0.47619, 0.251739, 0.42345, 0.426716, 0.44883, 0.485815, 0.489678, 0.49227, 0.507923, 0.527915, 0.552238
# elapsed time for k point: 0.8045539855957031
# solve_kpoint (0.52381,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 86 iterations.
# freqs:, 12, 0.52381, 0, 0, 0.52381, 0.251739, 0.423441, 0.426716, 0.448841, 0.485815, 0.489678, 0.492269, 0.507924, 0.527915, 0.535262
# elapsed time for k point: 3.2266945838928223
# solve_kpoint (0.571429,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 19 iterations.
# freqs:, 13, 0.571429, 0, 0, 0.571429, 0.246097, 0.392154, 0.424435, 0.44808, 0.448699, 0.460915, 0.465218, 0.469862, 0.508795, 0.548757
# elapsed time for k point: 0.7806618213653564
# solve_kpoint (0.619048,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# freqs:, 14, 0.619048, 0, 0, 0.619048, 0.235338, 0.356048, 0.393434, 0.40831, 0.422565, 0.423684, 0.437223, 0.478933, 0.494817, 0.530269
# elapsed time for k point: 0.40526270866394043
# solve_kpoint (0.666667,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 11 iterations.
# freqs:, 15, 0.666667, 0, 0, 0.666667, 0.220164, 0.316174, 0.350358, 0.36974, 0.38077, 0.384322, 0.433373, 0.474705, 0.478469, 0.520175
# elapsed time for k point: 0.4982450008392334
# solve_kpoint (0.714286,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 82 iterations.
# freqs:, 16, 0.714286, 0, 0, 0.714286, 0.201084, 0.273682, 0.307605, 0.33315, 0.34032, 0.345506, 0.418446, 0.458974, 0.459612, 0.469947
# elapsed time for k point: 3.022610902786255
# solve_kpoint (0.761905,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# freqs:, 17, 0.761905, 0, 0, 0.761905, 0.178138, 0.229543, 0.267022, 0.29882, 0.301833, 0.308418, 0.397205, 0.440128, 0.440498, 0.443717
# elapsed time for k point: 0.4582226276397705
# solve_kpoint (0.809524,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# freqs:, 18, 0.809524, 0, 0, 0.809524, 0.150796, 0.184414, 0.230487, 0.266202, 0.267394, 0.274149, 0.376588, 0.420923, 0.421885, 0.423214
# elapsed time for k point: 0.38614583015441895
# solve_kpoint (0.857143,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# freqs:, 19, 0.857143, 0, 0, 0.857143, 0.118423, 0.138694, 0.200177, 0.234759, 0.240001, 0.244084, 0.359245, 0.402241, 0.406309, 0.408655
# elapsed time for k point: 0.3912975788116455
# solve_kpoint (0.904762,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# freqs:, 20, 0.904762, 0, 0, 0.904762, 0.0814377, 0.0926234, 0.177632, 0.20942, 0.218244, 0.220057, 0.346287, 0.388319, 0.39444, 0.397679
# elapsed time for k point: 0.3816189765930176
# solve_kpoint (0.952381,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# freqs:, 21, 0.952381, 0, 0, 0.952381, 0.0414087, 0.0463562, 0.163627, 0.192619, 0.204034, 0.20427, 0.338304, 0.37971, 0.387016, 0.390861
# elapsed time for k point: 0.37753963470458984
# solve_kpoint (1,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 7 iterations.
# freqs:, 22, 1, 0, 0, 1, 1.7517e-05, 3.1175e-05, 0.158841, 0.186682, 0.198726, 0.199064, 0.335609, 0.376796, 0.38449, 0.388548
# elapsed time for k point: 0.3382251262664795
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.25173933867850384 at Vector3<0.5238095238095237, 0.0, 0.0>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.42344980473906607 at Vector3<0.47619047619047616, 0.0, 0.0>
# Band 3 range: 0.15884115437625448 at Vector3<0.0, 0.0, 0.0> to 0.42671599558250034 at Vector3<0.47619047619047616, 0.0, 0.0>
# Band 4 range: 0.18668142560469803 at Vector3<0.0, 0.0, 0.0> to 0.4488409076884176 at Vector3<0.5238095238095237, 0.0, 0.0>
# Band 5 range: 0.19872563637748916 at Vector3<0.0, 0.0, 0.0> to 0.48581464585711354 at Vector3<0.5238095238095237, 0.0, 0.0>
# Band 6 range: 0.1990642842356725 at Vector3<1.0, 0.0, 0.0> to 0.4896784460048232 at Vector3<0.5238095238095237, 0.0, 0.0>
# Band 7 range: 0.3356093517406852 at Vector3<0.0, 0.0, 0.0> to 0.4922696884948656 at Vector3<0.47619047619047616, 0.0, 0.0>
# Band 8 range: 0.3767952255186513 at Vector3<0.0, 0.0, 0.0> to 0.5079238832306534 at Vector3<0.5238095238095237, 0.0, 0.0>
# Band 9 range: 0.38448987442778476 at Vector3<0.0, 0.0, 0.0> to 0.5279151697592088 at Vector3<0.47619047619047616, 0.0, 0.0>
# Band 10 range: 0.38854848915770274 at Vector3<1.0, 0.0, 0.0> to 0.5606512643748895 at Vector3<0.42857142857142855, 0.0, 0.0>
# total elapsed time for run: 15.864039421081543
# done

# %% [markdown]
# We retrieve the bands from the file:

# %%
import os
path = os.path.abspath(os.getcwd())
print(path)
# Out:
# /home/ben/Desktop/Thesis/github/Thesis_name/Simulations/03_Periodic_Dielectric_Waveguides/2D_model

# %%
f = np.genfromtxt(path+"/data/2D_model_bands.dat", delimiter=",")[:-1,1:]

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.scatter(f[:,1], f[:,-10], c = 'blue', label='Even band') 
ax.scatter(f[:,1], f[:,-9], c = 'blue') 
ax.scatter(f[:,1], f[:,-6], c='green', label ='Odd band') 

ax.plot(np.linspace(0,0.5,100),np.linspace(0,0.5,100), c='r', label ='Light line')
ax.plot(np.linspace(0.5,1.0,100),1-np.linspace(0.5,1.0,100), c='r')
ax.fill_between(np.linspace(0,0.5,100), np.linspace(0,0.5,100), 0.5*np.ones(100), color='purple', alpha=0.8, label='Light cone') 
ax.fill_between(np.linspace(0.5,1,100), 1-np.linspace(0.5,1,100), 0.5*np.ones(100), color='purple', alpha=0.8) 

ax.set_title('Dispersion diagram for the 2D waveguide model')
ax.set_xlabel("Normalized $k_x$")
ax.set_ylabel("Frequency $\omega a / 2 \pi c$")
ax.set_xlim([0,1])
ax.set_ylim([0,0.5])
ax.legend()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# The Brioullin zone for the discontiguous strip is finite. The range between $\pi/a <k<2\pi/a$ is equivalent to $-\pi/a<k<0$ wich is the reverse of $0> k > \pi/a$. This leads to the apartition of a light cone. This also leads o a flattening at $\pi/a$ which bends downwards towards the end of the light cone. This causes a gap betweem the first two guided modes. This gap is however **incomplete** because guided modes are excluded from the gap, but radiating modes exist for any $\omega$.

# %% [markdown]
# ## Electric fields for bands

# %%
resolution = 32
md = mpb.MPBData(rectify=True, periods=3, resolution=resolution)

# %%
eps = ms.get_epsilon()
converted_eps = md.convert(eps).T
# Out:
# epsilon: 1-12, mean 1.352, harm. mean 1.03303, 3.55469% > 1, 3.2% "fill"

# %%
print(np.shape(converted_eps))
# Out:
# (480, 96)

# %%
plt.imshow(converted_eps[:160,:], interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=[mp.Vector3(0.5,0.0)],
    resolution=resolution,
    num_bands=num_bands
)

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run(mpb.output_at_kpoint(mp.Vector3(0.5, 0.0), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the dfields
md = mpb.MPBData(rectify=True, resolution=resolution, periods=3)

converted = []
for f in efields:
    # Get just the z component of the dfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

fig2, ax2 = plt.subplots(1,2,figsize=(14,6))
ax2[0].set_title('$E_z$ fields for first even band')
ax2[1].set_title('$E_z$ fields for first odd band')
ax2[0].contour(converted_eps[:160,:], cmap='binary')
ax2[1].contour(converted_eps[:160,:], cmap='binary')
posd1 = ax2[0].imshow(np.real(converted[0].T[:160,:]), interpolation='spline36', cmap='plasma')
posd2 = ax2[1].imshow(np.real(converted[4].T[:160,:]), interpolation='spline36', cmap='plasma')
ax2[0].set_xticks([])
ax2[0].set_xticklabels([]);
ax2[0].set_yticks([])
ax2[0].set_yticklabels([]);
ax2[1].set_xticks([])
ax2[1].set_xticklabels([]);
ax2[1].set_yticks([])
ax2[1].set_yticklabels([]);
fig.colorbar(posd1,ax=ax2[0])
fig.colorbar(posd2,ax=ax2[1])
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 160 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 5, 0)
#      (0, 0, 1)
# Cell volume = 5
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.2, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (-0.3,0,0)
#           size (0.4,0.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.037055253982543945
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 34 iterations.
# freqs:, 1, 0.5, 0, 0, 0.5, 0.252459, 0.426621, 0.436882, 0.437071, 0.488991, 0.510794, 0.511224, 0.513318, 0.516774, 0.524249
# elapsed time for k point: 1.1098556518554688
# Fixing e-field (band 1) phase by 0.275596 + -0.961274i; max ampl. = 0.868543
# Fixing e-field (band 2) phase by -0.307101 + -0.951677i; max ampl. = 0.913949
# Fixing e-field (band 3) phase by -0.968488 + 0.249059i; max ampl. = 0.779676
# Fixing e-field (band 4) phase by -0.947954 + 0.318407i; max ampl. = 1.44384
# Fixing e-field (band 5) phase by 0.0428869 + -0.99908i; max ampl. = 0.927338
# Fixing e-field (band 6) phase by 0.59478 + -0.803889i; max ampl. = 0.872549
# Fixing e-field (band 7) phase by 0.206818 + 0.978379i; max ampl. = 0.919233
# Fixing e-field (band 8) phase by 0.00368853 + -0.999993i; max ampl. = 0.945977
# Fixing e-field (band 9) phase by 0.0626259 + -0.998037i; max ampl. = 0.963376
# Fixing e-field (band 10) phase by -0.817851 + -0.575431i; max ampl. = 0.785033
# total elapsed time for run: 1.1742005348205566
# done

# %% [markdown]
# As we can see the odd mode has a higher frequency than the even one, which in turn leads to the band gap.  It is important to note that periodic dielectric waveguides have a finite amount of guided bands because frequencies rise and are pulled out to the light cone. There is as an upper frequency cutoff at $\omega=c\pi/a$.
