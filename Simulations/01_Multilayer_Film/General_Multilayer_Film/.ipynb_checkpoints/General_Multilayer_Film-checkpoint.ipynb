# %% [markdown]
# # Multilayer film
#
# ## Calculation of band structure

# %% [markdown]
# In this example we will try to **calculate the band structure with the first 2 modes of propagation** in the periodic 1D multilayer film. This 1D photonic crystal can be characterized as:

# %% [markdown]
# <img src="multilayer_film.png" width="800">

# %% [markdown]
# First of all, we load the necessary modules:

# %%
import meep as mp
from meep import mpb
import numpy as np

import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 16})

# %% [markdown]
# We fix the resolution:

# %%
resolution = 512 #we use a power of two number

# %% [markdown]
# We set the width of layers:

# %%
a = 1 #arbitrary units
w = 0.5 * a

# %% [markdown]
# We set the two mediums, with three posibilities for the second medium:

# %%
Med_1 = mp.Medium(index=np.sqrt(13))
Med_2_array = np.array([mp.Medium(index=np.sqrt(13)),mp.Medium(index=np.sqrt(12)),mp.Medium(index=1)])
num = len(Med_2_array)

# %% [markdown]
# Now we define the supercell:

# %%
sc_z = 1 * a  # supercell width

geometry_lattice = mp.Lattice(size=mp.Vector3(0,0,sc_z))

# %% [markdown]
# Now we define the geometry of our problem (remember, that the geometry is centered at $0$ and then takes possitive and negative values around it):

# %%
geometry_array = list()
for i in range(num):
    geometry_array.append([mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,-0.5*w), material=Med_1),mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,+0.5*w), material=Med_2_array[i])])

# %%
sim = mp.Simulation(resolution=128,
                    cell_size= mp.Vector3(0,0,1),
                    geometry=[mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,-0.5*w), material=Med_1),mp.Block(size=mp.Vector3(mp.inf, mp.inf, w),
                     center=mp.Vector3(0,0,+0.5*w), material=Med_2_array[2])])

sim.init_sim()

eps_data = sim.get_epsilon()
#from mayavi import mlab
#s = mlab.contour2d(eps_data, colormap="YlGnBu")
#mlab.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.05991e-06 s
# Working in 3D dimensions.
# Computational cell is 0.0078125 x 0.0078125 x 1 with resolution 128
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00240803 s
# -----------

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(np.linspace(0,1,len(eps_data)),eps_data)
ax.set_title('Dielectric profile for $\epsilon_1=13$ and $\epsilon_2=1$')
ax.set_xlabel('z (a units)')
ax.set_ylabel('$\epsilon$(z)')
# Out:
# Text(0, 0.5, '$\\epsilon$(z)')

# %% [markdown]
# As we can see it fulfills the change of $\epsilon$ at $z=0.5a$, as expected.

# %% [markdown]
# Now we set up the $k$-space (in our case we take into account that we want to check for the $k_z$ component):

# %%
num_bands = 6

num_k = 20
k_min = -0.5
k_max = 0.5

k_points = mp.interpolate(num_k, [mp.Vector3(0,0,k_min), mp.Vector3(0,0,k_max)])

# %% [markdown]
# We can now call the run function to compute the bands:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=k_points,
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 512.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 22 k-points
#   Vector3<0.0, 0.0, -0.5>
#   Vector3<0.0, 0.0, -0.4523809523809524>
#   Vector3<0.0, 0.0, -0.40476190476190477>
#   Vector3<0.0, 0.0, -0.35714285714285715>
#   Vector3<0.0, 0.0, -0.30952380952380953>
#   Vector3<0.0, 0.0, -0.2619047619047619>
#   Vector3<0.0, 0.0, -0.2142857142857143>
#   Vector3<0.0, 0.0, -0.16666666666666669>
#   Vector3<0.0, 0.0, -0.11904761904761907>
#   Vector3<0.0, 0.0, -0.07142857142857145>
#   Vector3<0.0, 0.0, -0.023809523809523836>
#   Vector3<0.0, 0.0, 0.023809523809523725>
#   Vector3<0.0, 0.0, 0.0714285714285714>
#   Vector3<0.0, 0.0, 0.11904761904761907>
#   Vector3<0.0, 0.0, 0.16666666666666663>
#   Vector3<0.0, 0.0, 0.2142857142857142>
#   Vector3<0.0, 0.0, 0.26190476190476186>
#   Vector3<0.0, 0.0, 0.30952380952380953>
#   Vector3<0.0, 0.0, 0.3571428571428571>
#   Vector3<0.0, 0.0, 0.40476190476190466>
#   Vector3<0.0, 0.0, 0.45238095238095233>
#   Vector3<0.0, 0.0, 0.5>
# elapsed time for initialization: 0.04524588584899902
# solve_kpoint (0,0,-0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# freqs:, 1, 0, 0, -0.5, 0.5, 0.150856, 0.150856, 0.256567, 0.256567, 0.590856, 0.590856
# elapsed time for k point: 0.020656824111938477
# solve_kpoint (0,0,-0.452381):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# freqs:, 2, 0, 0, -0.452381, 0.452381, 0.147698, 0.147698, 0.259496, 0.259496, 0.588676, 0.588676
# elapsed time for k point: 0.024663925170898438
# solve_kpoint (0,0,-0.404762):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 3, 0, 0, -0.404762, 0.404762, 0.139115, 0.139115, 0.267374, 0.267374, 0.582564, 0.582564
# elapsed time for k point: 0.03208446502685547
# solve_kpoint (0,0,-0.357143):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 4, 0, 0, -0.357143, 0.357143, 0.126847, 0.126847, 0.278402, 0.278402, 0.573518, 0.573518
# elapsed time for k point: 0.016973018646240234
# solve_kpoint (0,0,-0.309524):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 5, 0, 0, -0.309524, 0.309524, 0.112324, 0.112324, 0.291046, 0.291046, 0.562624, 0.562624
# elapsed time for k point: 0.04136395454406738
# solve_kpoint (0,0,-0.261905):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 6, 0, 0, -0.261905, 0.261905, 0.0964348, 0.0964348, 0.304245, 0.304245, 0.550825, 0.550825
# elapsed time for k point: 0.04406094551086426
# solve_kpoint (0,0,-0.214286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 7, 0, 0, -0.214286, 0.214286, 0.0796972, 0.0796972, 0.317214, 0.317214, 0.538921, 0.538921
# elapsed time for k point: 0.022034168243408203
# solve_kpoint (0,0,-0.166667):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 8, 0, 0, -0.166667, 0.166667, 0.0624193, 0.0624193, 0.329242, 0.329242, 0.527676, 0.527676
# elapsed time for k point: 0.044173240661621094
# solve_kpoint (0,0,-0.119048):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 9, 0, 0, -0.119048, 0.119048, 0.0447949, 0.0447949, 0.339551, 0.339551, 0.517913, 0.517913
# elapsed time for k point: 0.017819881439208984
# solve_kpoint (0,0,-0.0714286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 10, 0, 0, -0.0714286, 0.0714286, 0.0269552, 0.0269552, 0.347245, 0.347245, 0.510564, 0.510564
# elapsed time for k point: 0.01456451416015625
# solve_kpoint (0,0,-0.0238095):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 11, 0, 0, -0.0238095, 0.0238095, 0.00899761, 0.00899761, 0.351405, 0.351405, 0.506571, 0.506571
# elapsed time for k point: 0.04219841957092285
# solve_kpoint (0,0,0.0238095):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 12, 0, 0, 0.0238095, 0.0238095, 0.00899761, 0.00899761, 0.351405, 0.351405, 0.506571, 0.506571
# elapsed time for k point: 0.02318429946899414
# solve_kpoint (0,0,0.0714286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 13, 0, 0, 0.0714286, 0.0714286, 0.0269552, 0.0269552, 0.347245, 0.347245, 0.510564, 0.510564
# elapsed time for k point: 0.012223243713378906
# solve_kpoint (0,0,0.119048):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 14, 0, 0, 0.119048, 0.119048, 0.0447949, 0.0447949, 0.339551, 0.339551, 0.517913, 0.517913
# elapsed time for k point: 0.0382082462310791
# solve_kpoint (0,0,0.166667):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# freqs:, 15, 0, 0, 0.166667, 0.166667, 0.0624193, 0.0624193, 0.329242, 0.329242, 0.527676, 0.527676
# elapsed time for k point: 0.024118423461914062
# solve_kpoint (0,0,0.214286):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 16, 0, 0, 0.214286, 0.214286, 0.0796972, 0.0796972, 0.317214, 0.317214, 0.538921, 0.538921
# elapsed time for k point: 0.01677393913269043
# solve_kpoint (0,0,0.261905):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 17, 0, 0, 0.261905, 0.261905, 0.0964348, 0.0964348, 0.304245, 0.304245, 0.550825, 0.550825
# elapsed time for k point: 0.013891458511352539
# solve_kpoint (0,0,0.309524):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 18, 0, 0, 0.309524, 0.309524, 0.112324, 0.112324, 0.291046, 0.291046, 0.562624, 0.562624
# elapsed time for k point: 0.019199132919311523
# solve_kpoint (0,0,0.357143):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 19, 0, 0, 0.357143, 0.357143, 0.126847, 0.126847, 0.278402, 0.278402, 0.573518, 0.573518
# elapsed time for k point: 0.03380584716796875
# solve_kpoint (0,0,0.404762):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 20, 0, 0, 0.404762, 0.404762, 0.139115, 0.139115, 0.267374, 0.267374, 0.582564, 0.582564
# elapsed time for k point: 0.015566825866699219
# solve_kpoint (0,0,0.452381):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# freqs:, 21, 0, 0, 0.452381, 0.452381, 0.147698, 0.147698, 0.259496, 0.259496, 0.588676, 0.588676
# elapsed time for k point: 0.01799488067626953
# solve_kpoint (0,0,0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# freqs:, 22, 0, 0, 0.5, 0.5, 0.150856, 0.150856, 0.256567, 0.256567, 0.590856, 0.590856
# elapsed time for k point: 0.021952390670776367
# Band 1 range: 0.008997610306627683 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.15085583056045102 at Vector3<0.0, 0.0, 0.5>
# Band 2 range: 0.0089976112210934 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.15085583056045115 at Vector3<0.0, 0.0, 0.5>
# Band 3 range: 0.25656741892546603 at Vector3<0.0, 0.0, 0.5> to 0.35140531009139214 at Vector3<0.0, 0.0, -0.023809523809523836>
# Band 4 range: 0.25656741892546664 at Vector3<0.0, 0.0, 0.5> to 0.3514053101034182 at Vector3<0.0, 0.0, 0.023809523809523725>
# Band 5 range: 0.5065709720604413 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.5908555236832014 at Vector3<0.0, 0.0, -0.5>
# Band 6 range: 0.5065709720722904 at Vector3<0.0, 0.0, 0.023809523809523725> to 0.5908555272577617 at Vector3<0.0, 0.0, -0.5>
# Gap from band 2 (0.15085583056045115) to band 3 (0.25656741892546603), 51.892761887496974%
# Gap from band 4 (0.3514053101034182) to band 5 (0.5065709720604413), 36.1701518288332%
# total elapsed time for run: 0.6151492595672607
# done

# %% [markdown]
# We see that it works!

# %% [markdown]
# Now, we have passed everything down to `ms.py` and run for the three different geometries. We then generate some **band files** to plot them later. This was done by means of the `grep` command, i.e.: `grep freqs: data1.dat > bands_1.dat`. To access these files:

# %%
import os
path = os.path.abspath(os.getcwd())
print(path)
# Out:
# /home/ben/Desktop/Thesis/Simulations/01_Multilayer_Film/General_Multilayer_Film

# %%
f1 = np.genfromtxt(path+"/bands_1.dat", delimiter=",")[:-1,1:]
f2 = np.genfromtxt(path+"/bands_2.dat", delimiter=",")[:-1,1:]
f3 = np.genfromtxt(path+"/bands_3.dat", delimiter=",")[:-1,1:]

# %% [markdown]
# Now we plot the first two bands:

# %%
fig, ax = plt.subplots(1,3, figsize=(14,4))
f = [f1,f2,f3]
titles = ["For $\epsilon_2$=13","For $\epsilon_2$=12", "For $\epsilon_2$=1"]
for i in range(num):

    ax[i].plot(f[i][:,3], f[i][:,-8]) #in the files we calculated 8 bands, and we take the first 2! 
    ax[i].plot(f[i][:,3], f[i][:,-6]) # TE and TM modes will be the same so we jump by 2

    ax[i].set_title(titles[i])
    ax[i].set_xlabel("Normalized $k_z$")
    ax[i].set_ylabel("$\omega$")

# %% [markdown]
# In the first case, we expect the modes to lie along the light line: $\omega (k) = \frac{c k}{\sqrt(\epsilon)}$.

# %% [markdown]
# We also see the **appearance of a band-gap when the contrast of dielectric index is increased**!

# %% [markdown]
# ## Calculation of electromagnetic fields

# %% [markdown]
# Let's now see how to visualize the electric field related to both of these modes at the edge ($k=\frac{\pi}{a}$). First we simulate for the last geometry at the $k$ point:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0.5)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 512.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.5>
# elapsed time for initialization: 0.019863605499267578
# solve_kpoint (0,0,0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# freqs:, 1, 0, 0, 0.5, 0.5, 0.150856, 0.150856, 0.256567, 0.256567, 0.590856, 0.590856
# elapsed time for k point: 0.02122020721435547
# total elapsed time for run: 0.04124712944030762
# done

# %% [markdown]
# Now we get the real part of the electric field and calculate three periods for visualization purposes:

# %%
efield1 = np.real(np.reshape(ms.get_efield(2)[:,:,:,0],512)) # X component of field
efield2 = np.real(np.reshape(ms.get_efield(3) [:,:,:,0], 512)) # X component of field
efield1 = np.hstack([efield1,-efield1,efield1])
efield2 = np.hstack([efield2,-efield2,efield2])

# %% [markdown]
# Finally, we can plot the electric field for the first two bands on top of our geometry:

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(2,1,figsize=(16,12))
pos0 = ax[0].imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax[0])
ax[0].plot(efield1*1000+250, c='r', linewidth=4)
ax[0].invert_yaxis()
ax[0].set_title('$E$ field for mode at top of band $1$')
pos1 = ax[1].imshow(eps, cmap='Blues', )
fig.colorbar(pos1,ax=ax[1])
ax[1].plot(efield2*450+250, c='r', linewidth=4)
ax[1].invert_yaxis()
ax[1].set_title('$E$ field for mode at bottom of band $2$')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

for axis in ax:
    axis.set_xticks([])
    axis.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.86249, 50.1953% > 1, 50% "fill"

# %% [markdown]
# We can clearly see that **the electric field at top of band 1 has a higher frequency than the electric field at the bottom of band 2**!

# %% [markdown]
# Now, we want to see if the fields are stationary for different $k$-points. In theory, judging by the band structure, we should see that at $k=0$ and $k=\frac{\pi}{2 a}$ the group velocity goes to zero. This means that we expect stationary modes. At an intermediate $k$ we should see a propagating electric field. Let's put this to the test, starting with $k=\frac{\pi}{2 a}$:

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],512) # X component of field
efield2 = np.reshape(ms.get_efield(3) [:,:,:,0], 512) # X component of field
efield1 = np.hstack([efield1,-efield1,efield1])
efield2 = np.hstack([efield2,-efield2,efield2])

# %%
def add_phase(field, phase):
    import cmath
    r = np.zeros(len(field))
    theta = np.zeros(len(field))
    for i in range(len(field)):
        r[i],theta[i] = cmath.polar(field[i])
    theta += np.ones(len(field))*phase
    new_field = np.zeros(np.shape(field), dtype=np.complex_)
    for i in range(len(field)):
        new_field[i] = cmath.rect(r[i],theta[i])
    return  new_field

# %%
phases = np.linspace(0, 2*np.pi, 360)
fields = np.zeros((len(phases),np.size(efield1)), dtype=np.complex_)
for i in range(len(phases)):
    fields[i, :] = add_phase(efield1, phases[i])
fields = np.real(fields)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$ evolving with time')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)
ax.set_xticks([])
ax.set_yticks([])
line, = ax.plot([], [], lw=3, c='red')


def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0,len(efield1),len(efield1))
    y = fields[i]*1000+250
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=10, blit=True)


anim.save('electric_field1_k_edge.gif')

# %% [markdown]
# It looks as if the electric field is stationary, as we would expect!

# %% [markdown]
# Now, let's try for $k=0$:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 512.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01987624168395996
# solve_kpoint (0,0,0):
# Solving for bands 3 to 6...
# Finished solving for bands 3 to 6 after 10 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.351942, 0.351942, 0.506055, 0.506055
# elapsed time for k point: 0.014742851257324219
# total elapsed time for run: 0.03477120399475098
# done

# %%
def get_dephase(field):
    import cmath
    _ , theta0 = cmath.polar(field[0])
    _ , theta1 = cmath.polar(field[-1])
    return (theta1-theta0)

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],512) # X component of field
dephase = get_dephase(efield1)
efield1 = np.hstack([np.real(efield1),np.real(add_phase(efield1, dephase)),np.real(add_phase(efield1, 2*dephase))])

# %% [markdown]
# We have to correct the phase so it makes sense!

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax)
ax.plot(efield1*3000+250, c='r', linewidth=4)
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

ax.set_xticks([])
ax.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.86249, 50.1953% > 1, 50% "fill"
# []

# %%
phases = np.linspace(0, 8*np.pi, 360)
fields = np.zeros((len(phases),np.size(efield1)), dtype=np.complex_)
for i in range(len(phases)):
    fields[i, :] = add_phase(efield1, phases[i])
fields = np.real(fields)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$ evolving with time')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)
ax.set_xticks([])
ax.set_yticks([])
line, = ax.plot([], [], lw=3, c='red')


def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0,len(efield1),len(efield1))
    y = fields[i]*500+250
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


anim.save('electric_field1_k_0.gif')

# %% [markdown]
# Now, let's try for $k=0.25$:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0.25)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 512.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.25>
# elapsed time for initialization: 0.022976398468017578
# solve_kpoint (0,0,0.25):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# freqs:, 1, 0, 0, 0.25, 0.25, 0.0923152, 0.0923152, 0.307537, 0.307537, 0.547829, 0.547829
# elapsed time for k point: 0.02864551544189453
# total elapsed time for run: 0.05186867713928223
# done

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],512) # X component of field
dephase = get_dephase(efield1)
efield1 = np.hstack([np.real(efield1),np.real(add_phase(efield1, dephase)),np.real(add_phase(efield1, 2*dephase))])

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax)
ax.plot(efield1*600+250, c='r', linewidth=4)
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

ax.set_xticks([])
ax.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.86249, 50.1953% > 1, 50% "fill"
# []

# %%
efield1 = np.reshape(ms.get_efield(2)[:,:,:,0],512)
dephase = get_dephase(efield1)
efield1 = np.hstack([efield1,add_phase(efield1, dephase),add_phase(efield1, 2*dephase)])

phases = np.linspace(0, 8*np.pi, 360)
fields = np.zeros((len(phases),np.size(efield1)), dtype=np.complex_)
for i in range(len(phases)):
    fields[i, :] = add_phase(efield1, phases[i])
fields = np.real(fields)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig, ax = plt.subplots(figsize=(16,12))
pos0 = ax.imshow(eps, cmap='Blues')
ax.invert_yaxis()
ax.set_title('$E$ field for mode at top of band $1$ evolving with time')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)
ax.set_xticks([])
ax.set_yticks([])
line, = ax.plot([], [], lw=3, c='red')


def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0,len(efield1),len(efield1))
    y = fields[i]*600+250
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


anim.save('electric_field1_k_middle.gif')

# %% [markdown]
# ## Calculation of electromagnetic fields

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry_array[2],
                    k_points=[mp.Vector3(0,0,0.5)],
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 1 x 1 x 512.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.25)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 4 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.5>
# elapsed time for initialization: 0.016745567321777344
# solve_kpoint (0,0,0.5):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# freqs:, 1, 0, 0, 0.5, 0.5, 0.150856, 0.150856, 0.256567, 0.256567, 0.590856, 0.590856
# elapsed time for k point: 0.03806495666503906
# total elapsed time for run: 0.055097341537475586
# done

# %%
ms.get_dfield(2)
ms.compute_field_energy()
N = 512
energy0 = np.zeros(N)
for i in range(N):
    energy0 [i] = ms.get_energy_point(mp.Vector3(0,0,-0.5+(i/N)))
energy0 = np.hstack([energy0,energy0,energy0])
# Out:
# D-energy-components:, 1, 2, 0.60635, 0.39365, 0

# %%
ms.get_dfield(3)
ms.compute_field_energy()
energy1 = np.zeros(N)
for i in range(N):
    energy1 [i] = ms.get_energy_point(mp.Vector3(0,0,-0.5+(i/N)))
energy1 = np.hstack([energy1,energy1,energy1])
# Out:
# D-energy-components:, 1, 3, 0.162878, 0.837122, 0

# %%
eps = ms.get_epsilon();

eps = np.hstack([eps,eps,eps])

eps = np.repeat(eps[np.newaxis, :], resolution, axis=0)

fig, ax = plt.subplots(2,1,figsize=(16,12))
pos0 = ax[0].imshow(eps, cmap='Blues')
fig.colorbar(pos0,ax=ax[0])
ax[0].plot(energy0*200, c='r', linewidth=4)
ax[0].invert_yaxis()
ax[0].set_title('Local energy density in $E$ field for mode at top of band $1$')
pos1 = ax[1].imshow(eps, cmap='Blues', )
ax[0].fill_between(np.linspace(0,resolution*3,resolution*3),energy0*200, facecolor='red', alpha=0.5)
fig.colorbar(pos1,ax=ax[1])
ax[1].plot(energy1*120, c='r', linewidth=4)
ax[1].fill_between(np.linspace(0,resolution*3,resolution*3),energy1*120, facecolor='red', alpha=0.5)
ax[1].invert_yaxis()
ax[1].set_title('Local energy density in $E$ field for mode at bottom of band $2$')
plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

for axis in ax:
    axis.set_xticks([])
    axis.set_yticks([])
# Out:
# epsilon: 1-13, mean 7, harm. mean 1.86249, 50.1953% > 1, 50% "fill"

# %% [markdown]
# As we can see, **the energy tends to concentrate around high-$\varepsilon$ layers!** The gap arises from the difference in energy location.
