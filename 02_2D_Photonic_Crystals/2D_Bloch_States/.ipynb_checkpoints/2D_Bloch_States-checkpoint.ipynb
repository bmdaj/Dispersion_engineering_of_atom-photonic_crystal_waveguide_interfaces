# %% [markdown]
# # Two dimensional Bloch states

# %% [markdown]
# ## Band structure calculation

# %% [markdown]
# In this exercise we will get the band structure of the 2D Photonic crystal as depicted below:

# %% [markdown]
# <img src="media/2D_phot_crystal.png" width="700">

# %% [markdown]
# First of all,  let's  define modules and plottig preferences:

# %%
import meep as mp
from meep import mpb

import numpy as np

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})
# for Palatino and other serif fonts use:
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %% [markdown]
# We fix the resolution:

# %%
resolution = 128

# %% [markdown]
# Now we fix the mediums:

# %%
Med_1 = mp.Medium(index=np.sqrt(8.9)) #as in alumina
Med_2 = mp.Medium(index=1)

# %% [markdown]
# Next, we set the geometry:

# %%
a = 1 # arbitrary units
sc = 1 * a  

geometry_lattice = mp.Lattice(size=mp.Vector3(sc,sc,0))

# %%
r  = 0.2 * a
geometry = [mp.Cylinder(r, material=Med_1)]

# %% [markdown]
# We check if it makes sense:

# %%
sim = mp.Simulation(resolution=resolution,
                    cell_size= mp.Vector3(sc,sc,0),
                    geometry=geometry)
sim.init_sim()
eps_data = sim.get_epsilon()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 2D dimensions.
# Computational cell is 1 x 1 x 0 with resolution 128
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (8.9,8.9,8.9)
# time for set_epsilon = 0.0900881 s
# -----------

# %%
eps = np.concatenate([eps_data,eps_data,eps_data]) #three unit cells in one direction
eps = np.concatenate([eps.T,eps.T,eps.T]) # three fold repetition of a column of unit cells

fig1, ax1 = plt.subplots(figsize=(10,6))
ax1.set_title('3 $\\times$ 3 unit cells of the 2D photonic crystal')
pos1 = ax1.imshow(eps, interpolation='spline36', cmap='binary')
ax1.axis('off')
fig1.colorbar(pos1, ax=ax1)

# %% [markdown]
# It seems to be alright!

# %% [markdown]
# Now we set up the $k$-space:

# %%
num_bands = 8

num_k = 20

k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma

k_points = mp.interpolate(num_k, k_points)

# %% [markdown]
# We can now call the run function to compute the bands:

# %%
ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry,
                    k_points=k_points,
                    resolution=resolution,
                    num_bands=num_bands);
ms.run();
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 128 x 128 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 64 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.023809523809523808, 0.0, 0.0>
#   Vector3<0.047619047619047616, 0.0, 0.0>
#   Vector3<0.07142857142857142, 0.0, 0.0>
#   Vector3<0.09523809523809523, 0.0, 0.0>
#   Vector3<0.11904761904761904, 0.0, 0.0>
#   Vector3<0.14285714285714285, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.19047619047619047, 0.0, 0.0>
#   Vector3<0.21428571428571427, 0.0, 0.0>
#   Vector3<0.23809523809523808, 0.0, 0.0>
#   Vector3<0.26190476190476186, 0.0, 0.0>
#   Vector3<0.2857142857142857, 0.0, 0.0>
#   Vector3<0.30952380952380953, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.3571428571428571, 0.0, 0.0>
#   Vector3<0.38095238095238093, 0.0, 0.0>
#   Vector3<0.40476190476190477, 0.0, 0.0>
#   Vector3<0.42857142857142855, 0.0, 0.0>
#   Vector3<0.45238095238095233, 0.0, 0.0>
#   Vector3<0.47619047619047616, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.023809523809523808, 0.0>
#   Vector3<0.5, 0.047619047619047616, 0.0>
#   Vector3<0.5, 0.07142857142857142, 0.0>
#   Vector3<0.5, 0.09523809523809523, 0.0>
#   Vector3<0.5, 0.11904761904761904, 0.0>
#   Vector3<0.5, 0.14285714285714285, 0.0>
#   Vector3<0.5, 0.16666666666666666, 0.0>
#   Vector3<0.5, 0.19047619047619047, 0.0>
#   Vector3<0.5, 0.21428571428571427, 0.0>
#   Vector3<0.5, 0.23809523809523808, 0.0>
#   Vector3<0.5, 0.26190476190476186, 0.0>
#   Vector3<0.5, 0.2857142857142857, 0.0>
#   Vector3<0.5, 0.30952380952380953, 0.0>
#   Vector3<0.5, 0.3333333333333333, 0.0>
#   Vector3<0.5, 0.3571428571428571, 0.0>
#   Vector3<0.5, 0.38095238095238093, 0.0>
#   Vector3<0.5, 0.40476190476190477, 0.0>
#   Vector3<0.5, 0.42857142857142855, 0.0>
#   Vector3<0.5, 0.45238095238095233, 0.0>
#   Vector3<0.5, 0.47619047619047616, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.47619047619047616, 0.47619047619047616, 0.0>
#   Vector3<0.4523809523809524, 0.4523809523809524, 0.0>
#   Vector3<0.4285714285714286, 0.4285714285714286, 0.0>
#   Vector3<0.40476190476190477, 0.40476190476190477, 0.0>
#   Vector3<0.38095238095238093, 0.38095238095238093, 0.0>
#   Vector3<0.35714285714285715, 0.35714285714285715, 0.0>
#   Vector3<0.33333333333333337, 0.33333333333333337, 0.0>
#   Vector3<0.30952380952380953, 0.30952380952380953, 0.0>
#   Vector3<0.2857142857142857, 0.2857142857142857, 0.0>
#   Vector3<0.2619047619047619, 0.2619047619047619, 0.0>
#   Vector3<0.23809523809523814, 0.23809523809523814, 0.0>
#   Vector3<0.2142857142857143, 0.2142857142857143, 0.0>
#   Vector3<0.19047619047619047, 0.19047619047619047, 0.0>
#   Vector3<0.16666666666666669, 0.16666666666666669, 0.0>
#   Vector3<0.1428571428571429, 0.1428571428571429, 0.0>
#   Vector3<0.11904761904761907, 0.11904761904761907, 0.0>
#   Vector3<0.09523809523809523, 0.09523809523809523, 0.0>
#   Vector3<0.07142857142857145, 0.07142857142857145, 0.0>
#   Vector3<0.04761904761904767, 0.04761904761904767, 0.0>
#   Vector3<0.023809523809523836, 0.023809523809523836, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.05383658409118652
# solve_kpoint (0,0,0):
# Solving for bands 3 to 8...
# Finished solving for bands 3 to 8 after 18 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.582321, 0.627845, 0.627846, 0.628002, 0.823591, 0.823591
# elapsed time for k point: 1.0526087284088135
# solve_kpoint (0.0238095,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:, 2, 0.0238095, 0, 0, 0.0238095, 0.0168619, 0.0215281, 0.58105, 0.627826, 0.627889, 0.628981, 0.822051, 0.823741
# elapsed time for k point: 0.8497745990753174
# solve_kpoint (0.047619,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:,
0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:, 57, 0.166667, 0.166667, 0, 0.235702, 0.162142, 0.21236, 0.534557, 0.607467, 0.613037, 0.689236, 0.737546, 0.838915
# elapsed time for k point: 0.6963362693786621
# solve_kpoint (0.142857,0.142857,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:, 58, 0.142857, 0.142857, 0, 0.202031, 0.140147, 0.182206, 0.541783, 0.612459, 0.616607, 0.678419, 0.753789, 0.835174
# elapsed time for k point: 0.7047066688537598
# solve_kpoint (0.119048,0.119048,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# freqs:, 59, 0.119048, 0.119048, 0, 0.168359, 0.117579, 0.151964, 0.549615, 0.61691, 0.61984, 0.667521, 0.769924, 0.831824
# elapsed time for k point: 0.7239165306091309
# solve_kpoint (0.0952381,0.0952381,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# freqs:, 60, 0.0952381, 0.0952381, 0, 0.134687, 0.0945623, 0.121651, 0.557822, 0.620713, 0.622641, 0.6568, 0.785511, 0.828961
# elapsed time for k point: 0.7252416610717773
# solve_kpoint (0.0714286,0.0714286,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:, 61, 0.0714286, 0.0714286, 0, 0.101015, 0.0712047, 0.0912835, 0.566078, 0.623774, 0.624924, 0.646591, 0.799892, 0.826657
# elapsed time for k point: 0.736936092376709
# solve_kpoint (0.047619,0.047619,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:, 62, 0.047619, 0.047619, 0, 0.0673435, 0.0476018, 0.060877, 0.573808, 0.626017, 0.626614, 0.637469, 0.812051, 0.824968
# elapsed time for k point: 0.7037935256958008
# solve_kpoint (0.0238095,0.0238095,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# freqs:, 63, 0.0238095, 0.0238095, 0, 0.0336718, 0.0238399, 0.0304449, 0.579872, 0.627386, 0.627652, 0.630572, 0.820505, 0.823938
# elapsed time for k point: 0.7042498588562012
# solve_kpoint (0,0,0):
# Solving for bands 3 to 8...
# Finished solving for bands 3 to 8 after 8 iterations.
# freqs:, 64, 0, 0, 0, 0, 0, 0, 0.582321, 0.627845, 0.627846, 0.628002, 0.823591, 0.823591
# elapsed time for k point: 0.4543948173522949
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3224104475685471 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5488425552115245 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.4425139206372539 at Vector3<0.5, 0.0, 0.0> to 0.5823207681903046 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.46171217333097125 at Vector3<0.5, 0.0, 0.0> to 0.6278453208239055 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.5593843558619689 at Vector3<0.5, 0.38095238095238093, 0.0> to 0.6360010951422458 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.6018743842252643 at Vector3<0.5, 0.5, 0.0> to 0.7128460090956192 at Vector3<0.3333333333333333, 0.0, 0.0>
# Band 7 range: 0.6811340950259035 at Vector3<0.5, 0.5, 0.0> to 0.8235911994289249 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.6935809725619679 at Vector3<0.5, 0.5, 0.0> to 0.8843102558416014 at Vector3<0.5, 0.3571428571428571, 0.0>
# total elapsed time for run: 57.88748574256897
# done

# %% [markdown]
# Now, we have passed everything down to `ms_2D_pc.py` and run. We then generate some **band files** to plot them later. This was done by means of the `grep` command, i.e.: `grep freqs: 2D_pc_data.dat > 2D_pc_bands.dat`. To access the file:

# %%
import os
path = os.path.abspath(os.getcwd())
print(path)
# Out:
# /home/ben/Desktop/Thesis/github/Thesis_name/Simulations/02_2D_Photonic_Crystals/2D_Bloch_States

# %%
f = np.genfromtxt(path+"/data/2D_pc_bands.dat", delimiter=",")[:-1,1:]

# %%
fig, ax = plt.subplots(figsize=(14,10))
title = "Photonic bands structure for 2D PC with $\\varepsilon_1$=8.9 cylinders in air with $r=0.2a$"
ax.plot(np.linspace(0,len(f[:,-10]), len(f[:,-10])), f[:,-12], c='b' , label='TM mode') # TM mode
ax.plot(np.linspace(0,len(f[:,-10]), len(f[:,-10])), f[:,-11], c='r', label='TE mode') # TE mode
ax.plot(np.linspace(0,len(f[:,-10]), len(f[:,-10])), f[:,-10], c='b' ) # TM mode
ax.plot(np.linspace(0,len(f[:,-10]), len(f[:,-10])), f[:,-9], c='r' ) # TE mode
ax.plot(np.linspace(0,len(f[:,-10]), len(f[:,-10])), f[:,-8], c='b') # TM mode
plt.axvline(x=40, c='black', alpha=0.3)
plt.axvline(x=80, c='black', alpha=0.3)

ax.set_title(title)

ax.set_xticks([0, 40, 80, 120])
ax.set_xticklabels(['$\\Gamma$', 'X', 'M','$\\Gamma$'])
ax.set_xlim([0,120])
ax.set_xlabel("")
ax.set_ylabel("Frequency $\omega a / 2 \pi c$")
ax.legend(loc=4)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Now that we have the correct bands let's get we can plot the fields for the modes.

# %% [markdown]
# ## Electromagnetic field calculation

# %%
resolution = 512
md = mpb.MPBData(rectify=True, periods=3, resolution=resolution)

# %%
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
# Out:
# epsilon: 1-8.9, mean 1.99274, harm. mean 1.12896, 13.1897% > 1, 12.5664% "fill"

# %%
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=[mp.Vector3(0.5,0.5)],
    resolution=resolution,
    num_bands=num_bands
)

# %%
dfields = []

def get_dfields(ms, band):
    dfields.append(ms.get_dfield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(0.5, 0.5), mpb.fix_dfield_phase,
          get_dfields))

# Create an MPBData instance to transform the dfields
md = mpb.MPBData(rectify=True, resolution=resolution, periods=3)

converted = []
for f in dfields:
    # Get just the z component of the dfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

fig2, ax2 = plt.subplots(1,2,figsize=(16,6))
ax2[0].set_title('$D_z$ fields at $M$ (TM modes) for band 1')
ax2[1].set_title('$D_z$ fields at $M$ (TM modes) for band 2')
ax2[0].contour(converted_eps.T, cmap='binary')
ax2[1].contour(converted_eps.T, cmap='binary')
posd1 = ax2[0].imshow(np.real(converted[0]).T, interpolation='spline36', cmap='plasma')
posd2 = ax2[1].imshow(np.real(converted[1]).T, interpolation='spline36', cmap='plasma')
ax2[0].set_xticks([])
ax2[0].set_xticklabels([]);
ax2[0].set_yticks([])
ax2[0].set_yticklabels([]);
ax2[1].set_xticks([])
ax2[1].set_xticklabels([]);
ax2[1].set_yticks([])
ax2[1].set_yticklabels([]);
fig.colorbar(posd1,ax=ax2[0])
fig.colorbar(posd2,ax=ax2[1])
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 512 x 512 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.33818578720092773
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 15 iterations.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.707107, 0.322396, 0.548832, 0.548832, 0.693589, 0.922182, 0.922182, 0.981617, 0.989611
# elapsed time for k point: 70.50451064109802
# Fixing d-field (band 1) phase by -0.196821 + 0.980439i; max ampl. = 9.66121
# Fixing d-field (band 2) phase by 0.568707 + 0.82254i; max ampl. = 9.67704
# Fixing d-field (band 3) phase by -0.582421 + -0.812887i; max ampl. = 9.67711
# Fixing d-field (band 4) phase by 0.534395 + -0.845235i; max ampl. = 4.55787
# Fixing d-field (band 5) phase by 0.707707 + -0.706506i; max ampl. = 9.12715
# Fixing d-field (band 6) phase by 0.978136 + -0.207967i; max ampl. = 8.65392
# Fixing d-field (band 7) phase by -0.0356818 + 0.999363i; max ampl. = 11.9506
# Fixing d-field (band 8) phase by 0.407582 + -0.913169i; max ampl. = 17.9027
# total elapsed time for run: 71.65614414215088
# done

# %%
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=[mp.Vector3(0.5,0.0)],
    resolution=resolution,
    num_bands=num_bands
)

# %%
dfields = []

def get_dfields(ms, band):
    dfields.append(ms.get_dfield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(0.5,0.0), mpb.fix_dfield_phase,
          get_dfields))

# Create an MPBData instance to transform the dfields
md = mpb.MPBData(rectify=True, resolution=resolution, periods=3)

converted = []
for f in dfields:
    # Get just the z component of the dfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

fig2, ax2 = plt.subplots(1,2,figsize=(16,6))
ax2[0].set_title('$D_z$ fields at $X$ (TM modes) for band 1')
ax2[1].set_title('$D_z$ fields at $X$ (TM modes) for band 2')
ax2[0].contour(converted_eps.T, cmap='binary')
ax2[1].contour(converted_eps.T, cmap='binary')
posd1 = ax2[0].imshow(np.imag(converted[0]).T, interpolation='spline36', cmap='plasma')
posd2 = ax2[1].imshow(np.imag(converted[1]).T, interpolation='spline36', cmap='plasma')
ax2[0].set_xticks([])
ax2[0].set_xticklabels([]);
ax2[0].set_yticks([])
ax2[0].set_yticklabels([]);
ax2[1].set_xticks([])
ax2[1].set_xticklabels([]);
ax2[1].set_yticks([])
ax2[1].set_yticklabels([]);
fig.colorbar(posd1,ax=ax2[0])
fig.colorbar(posd2,ax=ax2[1])
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 512 x 512 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.3242175579071045
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 20 iterations.
# tmfreqs:, 1, 0.5, 0, 0, 0.5, 0.274707, 0.442518, 0.635957, 0.772239, 0.783949, 0.943092, 0.981342, 1.13638
# elapsed time for k point: 58.50622534751892
# Fixing d-field (band 1) phase by -0.494179 + 0.86936i; max ampl. = 8.78075
# Fixing d-field (band 2) phase by -0.694162 + -0.719819i; max ampl. = 6.86525
# Fixing d-field (band 3) phase by 0.0608629 + 0.998146i; max ampl. = 12.4066
# Fixing d-field (band 4) phase by -0.997543 + -0.0700525i; max ampl. = 9.89836
# Fixing d-field (band 5) phase by 0.403067 + 0.91517i; max ampl. = 9.88878
# Fixing d-field (band 6) phase by -0.543174 + -0.83962i; max ampl. = 11.3486
# Fixing d-field (band 7) phase by 0.670373 + -0.742024i; max ampl. = 12.4269
# Fixing d-field (band 8) phase by 0.113614 + 0.993525i; max ampl. = 16.5301
# total elapsed time for run: 59.58194065093994
# done

# %%
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=[mp.Vector3(0.0, 0.0)],
    resolution=resolution,
    num_bands=num_bands
)

# %%
dfields = []

def get_dfields(ms, band):
    dfields.append(ms.get_dfield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(0.0,0.0), mpb.fix_dfield_phase,
          get_dfields))

# Create an MPBData instance to transform the dfields
md = mpb.MPBData(rectify=True, resolution=resolution, periods=3)

converted = []
for f in dfields:
    # Get just the z component of the dfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

fig2, ax2 = plt.subplots(1,2,figsize=(16,6))
ax2[0].set_title('$D_z$ fields at $\\Gamma$ (TM modes) for band 1')
ax2[1].set_title('$D_z$ fields at $\\Gamma$ (TM modes) for band 2')
ax2[0].contour(converted_eps.T, cmap='binary')
ax2[1].contour(converted_eps.T, cmap='binary')
posd1 = ax2[0].imshow(np.real(converted[0]), interpolation='spline36', cmap='plasma')
posd2 = ax2[1].imshow(np.real(converted[1]), interpolation='spline36', cmap='plasma')
ax2[0].set_xticks([])
ax2[0].set_xticklabels([]);
ax2[0].set_yticks([])
ax2[0].set_yticklabels([]);
ax2[1].set_xticks([])
ax2[1].set_xticklabels([]);
ax2[1].set_yticks([])
ax2[1].set_yticklabels([]);
fig.colorbar(posd1,ax=ax2[0])
fig.colorbar(posd2,ax=ax2[1])
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 512 x 512 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.3197481632232666
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 18 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.582311, 0.627805, 0.627805, 0.889841, 0.972003, 1.06563, 1.12409
# elapsed time for k point: 34.845391273498535
# Fixing d-field (band 1) phase by 1 + -0i; max ampl. = 0
# Fixing d-field (band 2) phase by 0.955493 + -0.295015i; max ampl. = 9.86164
# Fixing d-field (band 3) phase by -0.0857494 + -0.996317i; max ampl. = 12.1704
# Fixing d-field (band 4) phase by 0.999937 + -0.0111958i; max ampl. = 12.1705
# Fixing d-field (band 5) phase by 0.45777 + 0.889071i; max ampl. = 10.4995
# Fixing d-field (band 6) phase by -0.533399 + -0.845864i; max ampl. = 13.3443
# Fixing d-field (band 7) phase by -0.0460542 + 0.998939i; max ampl. = 17.7137
# Fixing d-field (band 8) phase by -0.361774 + -0.932266i; max ampl. = 6.93415
# total elapsed time for run: 35.97643041610718
# done

# %% [markdown]
# As we can see the field associated to the lowest TM mode is mostly concentrated in the high dielectric regions. For the air band a nodal plane cuts through the dielectric columns, expelling some of the displacement field amplitude from the high dielectric region.

# %% [markdown]
# If we would inspect the TE modes, the contrast of the concentration factors would not be as strong. The contrast would be higher if there was a continuous dielectric pathway between rods that could contain the field lines of **D**.
